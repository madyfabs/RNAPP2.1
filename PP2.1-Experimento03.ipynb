# %% [markdown]
# # PP2.1 - Experimento III
#
# #### Alunos:
#    - Fabrício Mady
#    - Bernardo Kanekiyo

# %%
import numpy as np
import pandas as pd
import random
from random import  uniform
import statistics
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sn

# %% [markdown]
# ## Classe do neurônio

# %%
class Neuronio:
    
    def __init__(self):
        self.dados = np.array([])
        self.x_treino = np.array([])
        self.x_teste = np.array([])
        
        self.carrega_dados()
        
        self.pesos = np.array([
            uniform(-.5, .5),
            uniform(-.5, .5),
            uniform(-.5, .5)
        ])
        
        self.teta = 0
        self.ta   = 0.1
        self.vies = -1
        self.total_de_ajustes = []
        self.epocas = 0
        self.x1 = 0
        self.x2 = 0
        
    def carrega_dados_treino_e_teste(self):
        random.shuffle(self.dados)

        distribuicao = int(len(self.dados)*0.6)

        self.x_treino = self.dados[:distribuicao]
        self.x_teste  = self.dados[distribuicao:]
    
    def carrega_dados(self):
        dataset = np.fromfile('data/dataHoldout.txt')
        linhas  = len(dataset)//3
        colunas = 3
        self.dados = dataset.reshape(linhas, colunas)
        
        self.carrega_dados_treino_e_teste()
    
    def mostra_grafico(self):
        fig, ax = plt.subplots()
        for i in self.dados:
            x = i[0]
            y = i[1]
            yd = int(i[2])
            if(yd >= 1):
                plt.scatter(x,y, color='r', s=8)
            else:
                plt.scatter(x,y, color='b', s=8)

        ponto1 = [0,self.x1]
        ponto2 = [self.x2,0]
        x_values = [ponto1[0], ponto2[0]]
        y_values = [ponto1[1], ponto2[1]]

        ax.plot(x_values, y_values)
        plt.show()
        
    def funcao_ativacao(self,num):
        if (num>=self.teta):
            return 1
        else:
            return 0
        
    def perceptron(self):
        numero_de_ajustes = 0
        
        #Embaralha os dados
        self.dados = list(self.dados)
        random.shuffle(self.dados)
        self.dados = np.array(self.dados)
        
        print("Conjunto de dados embaralhado: \n",self.dados,"\n")
        
        for i in self.dados:
            
            entrada = np.concatenate((np.array([self.vies]), i[:2]))
            yd = int(i[2:])
            yr = round(entrada.dot(self.pesos),4)
            yr = self.funcao_ativacao(yr)
            
            numero_de_ajustes += 1
            self.pesos = self.ajuste_de_peso(yd, yr, entrada)
            
            if(yr != yd):
                self.total_de_ajustes.append(numero_de_ajustes)
                return False
            
        self.total_de_ajustes.append(numero_de_ajustes)
        return True

    def ajuste_de_peso(self, yd, yr, entrada):
        delta = self.ta * np.array(yd - yr).dot(entrada)
        novos_pesos = self.pesos + delta
        
        return novos_pesos
    
    def descobre_x1_x2(self):
        w = self.pesos
        
        w0_w2 = w[0]/w[2]
        w1_w2 = w[1]/w[2]

        self.x2 = w0_w2 - w1_w2 * 0
        self.x1 = w0_w2/w1_w2
    
    def treino(self):
        self.epocas = 1
        print("-----------------------------\nÉpoca: ",self.epocas,"\n")
        #100 epocas
        while(self.epocas<100):
            if(self.perceptron() == False):
                self.epocas += 1
                print("-----------------------------\nÉpoca: ",self.epocas,"\n")
            else:
                break
            
        self.descobre_x1_x2()

        print("Total de épocas: ",self.epocas)
        print("Total de ajustes feitos nos pesos: ",sum(self.total_de_ajustes))
        
n = Neuronio()

# %%
n.mostra_grafico()

# %%
n.dados = n.x_treino
n.treino()
# Out:
# -----------------------------
# Época:  1
#
# Conjunto de dados embaralhado:
#  [[ 0.30399699  0.00645548  1.        ]
#  [ 0.03195638 -0.10251385  1.        ]
#  [ 0.05786483 -0.36451414  1.        ]
#  ...
#  [-0.0754456   0.83677898  0.        ]
#  [-0.11636331  1.18067882  0.        ]
#  [-0.05039096 -0.43980938  1.        ]]
#
# -----------------------------
# Época:  2
#
# Conjunto de dados embaralhado:
#  [[ 0.32622018 -0.00707064  1.        ]
#  [-0.00474636  0.09826743  1.        ]
#  [ 0.27534583  0.92380154  0.        ]
#  ...
#  [ 0.02549432  0.87654871  0.        ]
#  [ 0.05786483 -0.36451414  1.        ]
#  [-0.37025595 -0.19697218  1.        ]]
#
# -----------------------------
# Época:  3
#
# Conjunto de dados embaralhado:
#  [[-0.11163154  0.00851976  1.        ]
#  [ 0.27238274  0.18359397  1.        ]
#  [-0.19908835  0.12926358  1.        ]
#  ...
#  [ 0.14139125  1.19105258  0.        ]
#  [ 0.15207387 -0.1526586   1.        ]
#  [ 0.07337792 -0.05966064  1.        ]]
#
# -----------------------------
# Época:  4
#
# Conjunto de dados embaralhado:
#  [[-0.20389569  0.36597829  1.        ]
#  [-0.0458408   0.0510611   1.        ]
#  [-0.10259311 -0.06961393  1.        ]
#  ...
#  [ 0.20300365  0.19595358  1.        ]
#  [ 0.03416729  0.17169338  1.        ]
#  [-0.12717344 -0.01477397  1.        ]]
#
# -----------------------------
# Época:  5
#
# Conjunto de dados embaralhado:
#  [[-0.22958441  1.05209844  0.        ]
#  [ 0.09743172  0.24002227  1.        ]
#  [ 0.89238603 -0.27421654  0.        ]
#  ...
#  [ 0.07785338  0.2471932   1.        ]
#  [-0.18164836  0.0789158   1.        ]
#  [ 0.06285892 -0.224167    1.        ]]
#
# -----------------------------
# Época:  6
#
# Conjunto de dados embaralhado:
#  [[ 0.19643799  0.20349331  1.        ]
#  [ 0.06285892 -0.224167    1.        ]
#  [-0.3001711   0.32724374  1.        ]
#  ...
#  [ 0.48892004 -0.13726797  1.        ]
#  [ 1.14121907  0.17148602  0.        ]
#  [ 0.96621959 -0.02305601  0.        ]]
#
# -----------------------------
# Época:  7
#
# Conjunto de dados embaralhado:
#  [[-0.22615337  0.1493509   1.        ]
#  [-0.24300515  0.15164356  1.        ]
#  [ 1.09934728  0.10419019  0.        ]
#  ...
#  [ 0.17537603  0.17826557  1.        ]
#  [-0.08879326 -0.07108222  1.        ]
#  [ 0.37222961  0.06930466  1.        ]]
#
# -----------------------------
# Época:  8
#
# Conjunto de dados embaralhado:
#  [[-0.0907412  -0.05805187  1.        ]
#  [-0.06282733 -0.32877261  1.        ]
#  [ 0.30399699  0.00645548  1.        ]
#  ...
#  [ 0.14347628  0.25927685  1.        ]
#  [-0.04716837  0.19363929  1.        ]
#  [ 0.97086504 -0.10384581  0.        ]]
#
# -----------------------------
# Época:  9
#
# Conjunto de dados embaralhado:
#  [[-0.22958441  1.05209844  0.        ]
#  [ 0.26394155  0.32750883  1.        ]
#  [-0.1576937   0.74716362  0.        ]
#  ...
#  [ 0.08690974  0.00654493  1.        ]
#  [ 0.15252857  0.01744889  1.        ]
#  [-0.00940128 -0.10654841  1.        ]]
#
# -----------------------------
# Época:  10
#
# Conjunto de dados embaralhado:
#  [[ 0.08179828 -0.09956027  1.        ]
#  [ 0.05369039  1.11695178  0.        ]
#  [ 0.29560862  0.08406349  1.        ]
#  ...
#  [ 0.90391945  0.14678532  0.        ]
#  [-0.22671361  0.21841371  1.        ]
#  [ 0.05786483 -0.36451414  1.        ]]
#
# -----------------------------
# Época:  11
#
# Conjunto de dados embaralhado:
#  [[ 0.05481746  1.01844515  0.        ]
#  [ 0.04322791 -0.0461912   1.        ]
#  [-0.04716837  0.19363929  1.        ]
#  ...
#  [ 0.19643799  0.20349331  1.        ]
#  [-0.29322959 -0.09065359  1.        ]
#  [-0.28552876 -0.16910219  1.        ]]
#
# -----------------------------
# Época:  12
#
# Conjunto de dados embaralhado:
#  [[-0.22958441  1.05209844  0.        ]
#  [-0.13398331  1.03761866  0.        ]
#  [ 0.14000195  1.0836725   0.        ]
#  ...
#  [-0.29322959 -0.09065359  1.        ]
#  [-0.10074294 -0.31860073  1.        ]
#  [ 0.19110701  0.2105866   1.        ]]
#
# -----------------------------
# Época:  13
#
# Conjunto de dados embaralhado:
#  [[-0.09408788  1.13557969  0.        ]
#  [ 0.06202681  0.75874289  0.        ]
#  [-0.06832331  1.1562397   0.        ]
#  ...
#  [-0.09127282  0.28768163  1.        ]
#  [-0.01465206  0.12680101  1.        ]
#  [-0.04347767 -0.18293735  1.        ]]
#
# -----------------------------
# Época:  14
#
# Conjunto de dados embaralhado:
#  [[ 0.03195638 -0.10251385  1.        ]
#  [-0.04716837  0.19363929  1.        ]
#  [-0.19908835  0.12926358  1.        ]
#  ...
#  [-0.22958441  1.05209844  0.        ]
#  [ 0.0824192   0.00106606  1.        ]
#  [ 0.06627455 -0.26057051  1.        ]]
#
# -----------------------------
# Época:  15
#
# Conjunto de dados embaralhado:
#  [[ 0.2123362   0.02517371  1.        ]
#  [ 0.0114998  -0.05939114  1.        ]
#  [-0.25504586  0.25995271  1.        ]
#  ...
#  [ 0.97608583  0.02046946  0.        ]
#  [ 0.04070907  0.1350255   1.        ]
#  [-0.23436994  0.03978647  1.        ]]
#
# -----------------------------
# Época:  16
#
# Conjunto de dados embaralhado:
#  [[ 0.01272533  0.20346543  1.        ]
#  [ 0.32606995  0.33196305  1.        ]
#  [ 0.20666057  1.07408362  0.        ]
#  ...
#  [-0.33000132  0.07234854  1.        ]
#  [ 0.36754371  0.0090821   1.        ]
#  [-0.01249701  1.13463856  0.        ]]
#
# -----------------------------
# Época:  17
#
# Conjunto de dados embaralhado:
#  [[-0.19791824  0.73077723  0.        ]
#  [ 0.31024232 -0.13097232  1.        ]
#  [ 0.20666057  1.07408362  0.        ]
#  ...
#  [ 0.28382866 -0.00689202  1.        ]
#  [ 0.07988839  0.21101297  1.        ]
#  [-0.33000132  0.07234854  1.        ]]
#
# -----------------------------
# Época:  18
#
# Conjunto de dados embaralhado:
#  [[ 1.27279874 -0.31974083  0.        ]
#  [-0.0180137   0.39719079  1.        ]
#  [ 0.28066172  0.13031361  1.        ]
#  ...
#  [-0.19087107  1.1429872   0.        ]
#  [-0.06832331  1.1562397   0.        ]
#  [-0.12531584  0.76885913  0.        ]]
#
# -----------------------------
# Época:  19
#
# Conjunto de dados embaralhado:
#  [[-0.10259311 -0.06961393  1.        ]
#  [ 0.06202681  0.75874289  0.        ]
#  [ 0.22245222 -0.2466912   1.        ]
#  ...
#  [-0.05049252 -0.25006668  1.        ]
#  [-0.19955665  0.86193762  0.        ]
#  [ 0.0824192   0.00106606  1.        ]]
#
# -----------------------------
# Época:  20
#
# Conjunto de dados embaralhado:
#  [[ 0.28066172  0.13031361  1.        ]
#  [-0.05049252 -0.25006668  1.        ]
#  [-0.00474636  0.09826743  1.        ]
#  ...
#  [-0.38616416  0.00437877  1.        ]
#  [ 0.14139125  1.19105258  0.        ]
#  [ 0.0114998  -0.05939114  1.        ]]
#
# -----------------------------
# Época:  21
#
# Conjunto de dados embaralhado:
#  [[-0.33711565  0.94927484  0.        ]
#  [ 0.2123362   0.02517371  1.        ]
#  [ 0.48892004 -0.13726797  1.        ]
#  ...
#  [ 0.30399699  0.00645548  1.        ]
#  [-0.09127282  0.28768163  1.        ]
#  [-0.04737586  0.93179216  0.        ]]
#
# -----------------------------
# Época:  22
#
# Conjunto de dados embaralhado:
#  [[-0.10671724 -0.00445963  1.        ]
#  [-0.06832331  1.1562397   0.        ]
#  [-0.05049252 -0.25006668  1.        ]
#  ...
#  [-0.05049252 -0.25006668  1.        ]
#  [ 0.97608583  0.02046946  0.        ]
#  [-0.33000132  0.07234854  1.        ]]
#
# -----------------------------
# Época:  23
#
# Conjunto de dados embaralhado:
#  [[-0.10391518  0.34638192  1.        ]
#  [ 0.07785338  0.2471932   1.        ]
#  [-0.22615337  0.1493509   1.        ]
#  ...
#  [-0.09127282  0.28768163  1.        ]
#  [ 0.07186273  1.07471211  0.        ]
#  [ 1.27279874 -0.31974083  0.        ]]
#
# -----------------------------
# Época:  24
#
# Conjunto de dados embaralhado:
#  [[-0.12490354  0.73283285  0.        ]
#  [-0.00474636  0.09826743  1.        ]
#  [ 0.25843371 -0.12301855  1.        ]
#  ...
#  [-0.04716837  0.19363929  1.        ]
#  [ 0.36729907  0.07514918  1.        ]
#  [ 0.21675147  0.54097717  1.        ]]
#
# -----------------------------
# Época:  25
#
# Conjunto de dados embaralhado:
#  [[-0.06282733 -0.32877261  1.        ]
#  [ 0.00842475  0.20229318  1.        ]
#  [ 0.83803793  0.04315289  0.        ]
#  ...
#  [-0.1985048   1.41827045  0.        ]
#  [-0.07617946  0.02320954  1.        ]
#  [ 0.29018767  0.89401935  0.        ]]
#
# -----------------------------
# Época:  26
#
# Conjunto de dados embaralhado:
#  [[-0.0294872   0.13216526  1.        ]
#  [ 0.10964344  0.67482285  0.        ]
#  [-0.28552876 -0.16910219  1.        ]
#  ...
#  [-0.19087107  1.1429872   0.        ]
#  [ 0.11700025  0.64151874  0.        ]
#  [-0.06865786 -0.18994482  1.        ]]
#
# -----------------------------
# Época:  27
#
# Conjunto de dados embaralhado:
#  [[-0.2502875   0.13876078  1.        ]
#  [ 1.4187099  -0.14253384  0.        ]
#  [-0.24300515  0.15164356  1.        ]
#  ...
#  [-0.0547258  -0.11131214  1.        ]
#  [-0.34226827  1.29302582  0.        ]
#  [-0.18164836  0.0789158   1.        ]]
#
# -----------------------------
# Época:  28
#
# Conjunto de dados embaralhado:
#  [[ 0.07988839  0.21101297  1.        ]
#  [ 0.26985956  0.87102575  0.        ]
#  [-0.46833414 -0.10620722  1.        ]
#  ...
#  [-0.21901569 -0.28125484  1.        ]
#  [-0.02215321  0.00269713  1.        ]
#  [-0.04148642  0.99913985  0.        ]]
#
# -----------------------------
# Época:  29
#
# Conjunto de dados embaralhado:
#  [[-0.11636331  1.18067882  0.        ]
#  [-0.04347767 -0.18293735  1.        ]
#  [-0.03486406  1.15509737  0.        ]
#  ...
#  [ 0.08690974  0.00654493  1.        ]
#  [-0.29322959 -0.09065359  1.        ]
#  [ 0.12020386  0.40989806  1.        ]]
#
# -----------------------------
# Época:  30
#
# Conjunto de dados embaralhado:
#  [[ 0.07957988  1.12760559  0.        ]
#  [ 0.05481746  1.01844515  0.        ]
#  [ 0.29560862  0.08406349  1.        ]
#  ...
#  [ 0.96621959 -0.02305601  0.        ]
#  [-0.23593942  0.18670953  1.        ]
#  [ 0.48892004 -0.13726797  1.        ]]
#
# -----------------------------
# Época:  31
#
# Conjunto de dados embaralhado:
#  [[-0.09807031  0.88862768  0.        ]
#  [ 0.05481746  1.01844515  0.        ]
#  [ 0.1460631   0.1776204   1.        ]
#  ...
#  [ 0.35751084 -0.30883258  1.        ]
#  [ 0.34015635  0.06961302  1.        ]
#  [-0.2502875   0.13876078  1.        ]]
#
# -----------------------------
# Época:  32
#
# Conjunto de dados embaralhado:
#  [[ 1.27279874 -0.31974083  0.        ]
#  [ 0.29018767  0.89401935  0.        ]
#  [-0.13398331  1.03761866  0.        ]
#  ...
#  [-0.03197237  0.16450966  1.        ]
#  [ 0.26482475  0.03523472  1.        ]
#  [ 0.26072056 -0.14729552  1.        ]]
#
# -----------------------------
# Época:  33
#
# Conjunto de dados embaralhado:
#  [[-0.2502875   0.13876078  1.        ]
#  [-0.1985048   1.41827045  0.        ]
#  [ 0.06627455 -0.26057051  1.        ]
#  ...
#  [ 0.21312794  0.95303668  0.        ]
#  [-0.04716837  0.19363929  1.        ]
#  [ 0.34015635  0.06961302  1.        ]]
#
# -----------------------------
# Época:  34
#
# Conjunto de dados embaralhado:
#  [[-0.11163154  0.00851976  1.        ]
#  [ 0.22245222 -0.2466912   1.        ]
#  [ 0.35751084 -0.30883258  1.        ]
#  ...
#  [ 0.07988839  0.21101297  1.        ]
#  [ 0.09743172  0.24002227  1.        ]
#  [ 1.14121907  0.17148602  0.        ]]
#
# -----------------------------
# Época:  35
#
# Conjunto de dados embaralhado:
#  [[-0.04254102  0.26891466  1.        ]
#  [-0.25504586  0.25995271  1.        ]
#  [ 0.35751084 -0.30883258  1.        ]
#  ...
#  [ 0.00976696 -0.02053641  1.        ]
#  [ 0.21265355  0.2789915   1.        ]
#  [-0.14967201 -0.19512452  1.        ]]
#
# -----------------------------
# Época:  36
#
# Conjunto de dados embaralhado:
#  [[ 0.07028775  0.39056305  1.        ]
#  [-0.06856801  0.16646269  1.        ]
#  [ 0.25776183  0.03455125  1.        ]
#  ...
#  [ 0.07988839  0.21101297  1.        ]
#  [ 0.12052833  0.52761443  1.        ]
#  [ 0.37222961  0.06930466  1.        ]]
#
# -----------------------------
# Época:  37
#
# Conjunto de dados embaralhado:
#  [[ 0.12020386  0.40989806  1.        ]
#  [-0.00474636  0.09826743  1.        ]
#  [ 0.19110701  0.2105866   1.        ]
#  ...
#  [ 0.3509719   0.01024045  1.        ]
#  [-0.19217896  1.04049856  0.        ]
#  [-0.1882854   0.85202358  0.        ]]
#
# -----------------------------
# Época:  38
#
# Conjunto de dados embaralhado:
#  [[ 0.8098433   0.07540675  0.        ]
#  [ 0.35751084 -0.30883258  1.        ]
#  [ 0.05786483 -0.36451414  1.        ]
#  ...
#  [-0.027351   -0.14271275  1.        ]
#  [ 0.01035887  0.19358383  1.        ]
#  [ 1.2474059   0.03330428  0.        ]]
#
# -----------------------------
# Época:  39
#
# Conjunto de dados embaralhado:
#  [[ 0.26852925  1.03941518  0.        ]
#  [ 0.10964344  0.67482285  0.        ]
#  [ 0.17537603  0.17826557  1.        ]
#  ...
#  [-0.21442938  0.00797897  1.        ]
#  [ 0.14927021  0.30009393  1.        ]
#  [-0.26652617 -0.02689509  1.        ]]
#
# -----------------------------
# Época:  40
#
# Conjunto de dados embaralhado:
#  [[-0.05213949 -0.05768201  1.        ]
#  [ 0.46304142  0.09405471  1.        ]
#  [-0.02677506  0.19158953  1.        ]
#  ...
#  [-0.12531584  0.76885913  0.        ]
#  [ 0.26394155  0.32750883  1.        ]
#  [ 1.05955133 -0.10563685  0.        ]]
#
# -----------------------------
# Época:  41
#
# Conjunto de dados embaralhado:
#  [[-0.13398331  1.03761866  0.        ]
#  [ 0.97086504 -0.10384581  0.        ]
#  [-0.0458408   0.0510611   1.        ]
#  ...
#  [-0.03134909  1.34302578  0.        ]
#  [ 0.2123362   0.02517371  1.        ]
#  [ 1.4187099  -0.14253384  0.        ]]
#
# -----------------------------
# Época:  42
#
# Conjunto de dados embaralhado:
#  [[ 0.32622018 -0.00707064  1.        ]
#  [-0.18164836  0.0789158   1.        ]
#  [ 0.05786483 -0.36451414  1.        ]
#  ...
#  [ 0.00394505  0.1408983   1.        ]
#  [-0.28552876 -0.16910219  1.        ]
#  [ 1.05955133 -0.10563685  0.        ]]
#
# -----------------------------
# Época:  43
#
# Conjunto de dados embaralhado:
#  [[ 0.20666057  1.07408362  0.        ]
#  [ 0.2367801   0.37531654  1.        ]
#  [ 0.26072056 -0.14729552  1.        ]
#  ...
#  [-0.02215321  0.00269713  1.        ]
#  [-0.09643162 -0.23454603  1.        ]
#  [ 0.09475184  0.00442865  1.        ]]
#
# -----------------------------
# Época:  44
#
# Conjunto de dados embaralhado:
#  [[-0.03197237  0.16450966  1.        ]
#  [ 0.07988839  0.21101297  1.        ]
#  [ 0.12020386  0.40989806  1.        ]
#  ...
#  [-0.29322959 -0.09065359  1.        ]
#  [-0.17369552 -0.02572443  1.        ]
#  [ 0.06285892 -0.224167    1.        ]]
#
# -----------------------------
# Época:  45
#
# Conjunto de dados embaralhado:
#  [[ 0.08179828 -0.09956027  1.        ]
#  [-0.02215321  0.00269713  1.        ]
#  [ 0.07988839  0.21101297  1.        ]
#  ...
#  [-0.12717344 -0.01477397  1.        ]
#  [-0.06282733 -0.32877261  1.        ]
#  [-0.21442938  0.00797897  1.        ]]
#
# -----------------------------
# Época:  46
#
# Conjunto de dados embaralhado:
#  [[ 0.11700025  0.64151874  0.        ]
#  [ 0.24709879 -0.16289625  1.        ]
#  [-0.07994656  1.09548869  0.        ]
#  ...
#  [-0.03486406  1.15509737  0.        ]
#  [-0.31310084  0.27736732  1.        ]
#  [ 0.05786483 -0.36451414  1.        ]]
#
# -----------------------------
# Época:  47
#
# Conjunto de dados embaralhado:
#  [[-0.0054924  -0.30231266  1.        ]
#  [ 0.97608583  0.02046946  0.        ]
#  [ 0.0748692  -0.03487411  1.        ]
#  ...
#  [ 0.1196882   0.08875686  1.        ]
#  [-0.05049252 -0.25006668  1.        ]
#  [ 0.03416729  0.17169338  1.        ]]
#
# -----------------------------
# Época:  48
#
# Conjunto de dados embaralhado:
#  [[-0.10391518  0.34638192  1.        ]
#  [ 0.09743172  0.24002227  1.        ]
#  [ 1.0430164  -0.00601379  0.        ]
#  ...
#  [-0.28552876 -0.16910219  1.        ]
#  [-0.10671724 -0.00445963  1.        ]
#  [ 0.10944287  0.97542507  0.        ]]
#
# -----------------------------
# Época:  49
#
# Conjunto de dados embaralhado:
#  [[ 8.38037930e-01  4.31528872e-02  0.00000000e+00]
#  [ 6.62745490e-02 -2.60570514e-01  1.00000000e+00]
#  [-3.30001322e-01  7.23485438e-02  1.00000000e+00]
#  ...
#  [ 1.14121907e+00  1.71486015e-01  0.00000000e+00]
#  [ 8.24192013e-02  1.06606167e-03  1.00000000e+00]
#  [-8.26856279e-02 -2.70872799e-01  1.00000000e+00]]
#
# -----------------------------
# Época:  50
#
# Conjunto de dados embaralhado:
#  [[-0.04148642  0.99913985  0.        ]
#  [ 1.27271431 -0.30512302  0.        ]
#  [ 0.01035887  0.19358383  1.        ]
#  ...
#  [-0.0031101   0.18965456  1.        ]
#  [-0.10038537 -0.60750339  1.        ]
#  [-0.1985048   1.41827045  0.        ]]
#
# -----------------------------
# Época:  51
#
# Conjunto de dados embaralhado:
#  [[-0.08879326 -0.07108222  1.        ]
#  [-0.46833414 -0.10620722  1.        ]
#  [-0.09127282  0.28768163  1.        ]
#  ...
#  [ 0.26072056 -0.14729552  1.        ]
#  [ 0.25527419  0.17171587  1.        ]
#  [-0.33711565  0.94927484  0.        ]]
#
# -----------------------------
# Época:  52
#
# Conjunto de dados embaralhado:
#  [[ 0.1196882   0.08875686  1.        ]
#  [ 0.26394155  0.32750883  1.        ]
#  [ 0.0748692  -0.03487411  1.        ]
#  ...
#  [-0.29330698 -0.055651    1.        ]
#  [ 0.08298076  0.12868493  1.        ]
#  [ 0.15640596  0.84981368  0.        ]]
#
# -----------------------------
# Época:  53
#
# Conjunto de dados embaralhado:
#  [[-0.12350761  0.14385352  1.        ]
#  [-0.07113236  1.08579579  0.        ]
#  [-0.01442025 -0.02745483  1.        ]
#  ...
#  [ 0.08179828 -0.09956027  1.        ]
#  [ 0.32606995  0.33196305  1.        ]
#  [-0.19955665  0.86193762  0.        ]]
#
# -----------------------------
# Época:  54
#
# Conjunto de dados embaralhado:
#  [[ 0.07988839  0.21101297  1.        ]
#  [-0.29322959 -0.09065359  1.        ]
#  [ 0.00866547  0.79757433  0.        ]
#  ...
#  [ 0.08298076  0.12868493  1.        ]
#  [-0.28552876 -0.16910219  1.        ]
#  [ 0.21312794  0.95303668  0.        ]]
#
# -----------------------------
# Época:  55
#
# Conjunto de dados embaralhado:
#  [[-0.14967201 -0.19512452  1.        ]
#  [ 0.29560862  0.08406349  1.        ]
#  [-0.04716837  0.19363929  1.        ]
#  ...
#  [-0.25504586  0.25995271  1.        ]
#  [-0.07825563 -0.08083512  1.        ]
#  [-0.22671361  0.21841371  1.        ]]
#
# -----------------------------
# Época:  56
#
# Conjunto de dados embaralhado:
#  [[-0.19908835  0.12926358  1.        ]
#  [-0.06282733 -0.32877261  1.        ]
#  [ 0.09475184  0.00442865  1.        ]
#  ...
#  [ 0.32202822  0.9463054   0.        ]
#  [-0.06282733 -0.32877261  1.        ]
#  [-0.1882854   0.85202358  0.        ]]
#
# -----------------------------
# Época:  57
#
# Conjunto de dados embaralhado:
#  [[-0.0054924  -0.30231266  1.        ]
#  [ 0.25776183  0.03455125  1.        ]
#  [ 0.14927021  0.30009393  1.        ]
#  ...
#  [ 0.05786483 -0.36451414  1.        ]
#  [-0.07113236  1.08579579  0.        ]
#  [-0.21901569 -0.28125484  1.        ]]
#
# -----------------------------
# Época:  58
#
# Conjunto de dados embaralhado:
#  [[-0.19217896  1.04049856  0.        ]
#  [-0.19908835  0.12926358  1.        ]
#  [ 0.12020386  0.40989806  1.        ]
#  ...
#  [-0.05049252 -0.25006668  1.        ]
#  [ 0.25527419  0.17171587  1.        ]
#  [ 1.4187099  -0.14253384  0.        ]]
#
# -----------------------------
# Época:  59
#
# Conjunto de dados embaralhado:
#  [[ 0.09475184  0.00442865  1.        ]
#  [-0.01465206  0.12680101  1.        ]
#  [-0.33000132  0.07234854  1.        ]
#  ...
#  [ 0.29560862  0.08406349  1.        ]
#  [-0.01442025 -0.02745483  1.        ]
#  [-0.12695428  0.74982337  0.        ]]
#
# -----------------------------
# Época:  60
#
# Conjunto de dados embaralhado:
#  [[-0.00474636  0.09826743  1.        ]
#  [ 0.00976696 -0.02053641  1.        ]
#  [ 0.25776183  0.03455125  1.        ]
#  ...
#  [ 0.14814828  1.19025708  0.        ]
#  [-0.38616416  0.00437877  1.        ]
#  [ 0.04253339  0.4469942   1.        ]]
#
# -----------------------------
# Época:  61
#
# Conjunto de dados embaralhado:
#  [[ 0.0114998  -0.05939114  1.        ]
#  [-0.29330698 -0.055651    1.        ]
#  [ 0.25527419  0.17171587  1.        ]
#  ...
#  [-0.22615337  0.1493509   1.        ]
#  [-0.26652617 -0.02689509  1.        ]
#  [-0.05049252 -0.25006668  1.        ]]
#
# -----------------------------
# Época:  62
#
# Conjunto de dados embaralhado:
#  [[-0.10038537 -0.60750339  1.        ]
#  [-0.10391518  0.34638192  1.        ]
#  [ 1.4187099  -0.14253384  0.        ]
#  ...
#  [-0.09127282  0.28768163  1.        ]
#  [-0.20389569  0.36597829  1.        ]
#  [ 0.0474884   0.76108048  0.        ]]
#
# -----------------------------
# Época:  63
#
# Conjunto de dados embaralhado:
#  [[-0.04162565  0.12822745  1.        ]
#  [ 0.16775772  0.22831062  1.        ]
#  [ 0.08690974  0.00654493  1.        ]
#  ...
#  [ 0.19028998 -0.01032709  1.        ]
#  [-0.04148642  0.99913985  0.        ]
#  [ 0.07988839  0.21101297  1.        ]]
#
# -----------------------------
# Época:  64
#
# Conjunto de dados embaralhado:
#  [[ 0.07957988  1.12760559  0.        ]
#  [ 0.15207387 -0.1526586   1.        ]
#  [ 0.28066172  0.13031361  1.        ]
#  ...
#  [ 0.05824952 -0.07760549  1.        ]
#  [ 1.09934728  0.10419019  0.        ]
#  [ 0.9692525  -0.10775797  0.        ]]
#
# -----------------------------
# Época:  65
#
# Conjunto de dados embaralhado:
#  [[-0.46833414 -0.10620722  1.        ]
#  [-0.0458408   0.0510611   1.        ]
#  [ 0.29560862  0.08406349  1.        ]
#  ...
#  [ 0.06627455 -0.26057051  1.        ]
#  [-0.04737586  0.93179216  0.        ]
#  [ 0.14555276  0.70970773  0.        ]]
#
# -----------------------------
# Época:  66
#
# Conjunto de dados embaralhado:
#  [[ 0.11700025  0.64151874  0.        ]
#  [ 0.2123362   0.02517371  1.        ]
#  [ 0.24709879 -0.16289625  1.        ]
#  ...
#  [-0.22615337  0.1493509   1.        ]
#  [ 1.09934728  0.10419019  0.        ]
#  [-0.26839638  1.12152776  0.        ]]
#
# -----------------------------
# Época:  67
#
# Conjunto de dados embaralhado:
#  [[-0.05213949 -0.05768201  1.        ]
#  [ 0.03645874 -0.23372151  1.        ]
#  [ 0.29560862  0.08406349  1.        ]
#  ...
#  [ 0.07988839  0.21101297  1.        ]
#  [-0.07722405  0.18953338  1.        ]
#  [ 0.64242708  0.77462397  0.        ]]
#
# -----------------------------
# Época:  68
#
# Conjunto de dados embaralhado:
#  [[ 1.4187099  -0.14253384  0.        ]
#  [ 0.05786483 -0.36451414  1.        ]
#  [-0.03197237  0.16450966  1.        ]
#  ...
#  [ 0.64242708  0.77462397  0.        ]
#  [-0.06282733 -0.32877261  1.        ]
#  [ 0.34015635  0.06961302  1.        ]]
#
# -----------------------------
# Época:  69
#
# Conjunto de dados embaralhado:
#  [[-0.00940128 -0.10654841  1.        ]
#  [ 0.64242708  0.77462397  0.        ]
#  [ 0.28066172  0.13031361  1.        ]
#  ...
#  [ 0.36729907  0.07514918  1.        ]
#  [ 1.14121907  0.17148602  0.        ]
#  [-0.05213949 -0.05768201  1.        ]]
#
# -----------------------------
# Época:  70
#
# Conjunto de dados embaralhado:
#  [[-0.05049252 -0.25006668  1.        ]
#  [-0.18777062  0.42687831  1.        ]
#  [ 0.07337792 -0.05966064  1.        ]
#  ...
#  [-0.04716837  0.19363929  1.        ]
#  [ 0.15252857  0.01744889  1.        ]
#  [-0.07617946  0.02320954  1.        ]]
#
# -----------------------------
# Época:  71
#
# Conjunto de dados embaralhado:
#  [[-0.07617946  0.02320954  1.        ]
#  [ 1.14121907  0.17148602  0.        ]
#  [ 0.08948218 -0.22242627  1.        ]
#  ...
#  [ 0.36729907  0.07514918  1.        ]
#  [ 1.02800469 -0.15938552  0.        ]
#  [ 0.89238603 -0.27421654  0.        ]]
#
# -----------------------------
# Época:  72
#
# Conjunto de dados embaralhado:
#  [[-0.03197237  0.16450966  1.        ]
#  [-0.0054924  -0.30231266  1.        ]
#  [ 0.22245222 -0.2466912   1.        ]
#  ...
#  [ 0.04070907  0.1350255   1.        ]
#  [ 0.14927021  0.30009393  1.        ]
#  [ 0.14000195  1.0836725   0.        ]]
#
# -----------------------------
# Época:  73
#
# Conjunto de dados embaralhado:
#  [[ 0.26482475  0.03523472  1.        ]
#  [-0.23593942  0.18670953  1.        ]
#  [-0.0150527  -0.12832773  1.        ]
#  ...
#  [-0.21442938  0.00797897  1.        ]
#  [ 1.23001937  0.05256076  0.        ]
#  [-0.1985048   1.41827045  0.        ]]
#
# -----------------------------
# Época:  74
#
# Conjunto de dados embaralhado:
#  [[-0.2175649  -0.24798023  1.        ]
#  [-0.20009509  0.37511566  1.        ]
#  [-0.22671361  0.21841371  1.        ]
#  ...
#  [-0.14248429  0.77449017  0.        ]
#  [ 0.09509565  0.35550407  1.        ]
#  [-0.19689787  1.41816483  0.        ]]
#
# -----------------------------
# Época:  75
#
# Conjunto de dados embaralhado:
#  [[ 1.2474059   0.03330428  0.        ]
#  [-0.18164836  0.0789158   1.        ]
#  [-0.05213949 -0.05768201  1.        ]
#  ...
#  [-0.07849193  1.09714508  0.        ]
#  [-0.08041492 -0.18693755  1.        ]
#  [ 0.25776183  0.03455125  1.        ]]
#
# -----------------------------
# Época:  76
#
# Conjunto de dados embaralhado:
#  [[ 0.07785338  0.2471932   1.        ]
#  [ 0.25527419  0.17171587  1.        ]
#  [ 0.2123362   0.02517371  1.        ]
#  ...
#  [-0.21748562  0.03151915  1.        ]
#  [ 0.12052833  0.52761443  1.        ]
#  [ 0.96621959 -0.02305601  0.        ]]
#
# -----------------------------
# Época:  77
#
# Conjunto de dados embaralhado:
#  [[-0.18621973  0.85732348  0.        ]
#  [ 0.28066172  0.13031361  1.        ]
#  [ 0.26482475  0.03523472  1.        ]
#  ...
#  [-0.1882854   0.85202358  0.        ]
#  [-0.29322959 -0.09065359  1.        ]
#  [ 0.28066172  0.13031361  1.        ]]
#
# -----------------------------
# Época:  78
#
# Conjunto de dados embaralhado:
#  [[ 0.48892004 -0.13726797  1.        ]
#  [ 0.19028998 -0.01032709  1.        ]
#  [ 1.23001937  0.05256076  0.        ]
#  ...
#  [ 0.6876728   0.14567997  0.        ]
#  [ 0.1639115   1.17985216  0.        ]
#  [-0.31310084  0.27736732  1.        ]]
#
# -----------------------------
# Época:  79
#
# Conjunto de dados embaralhado:
#  [[ 0.30575683  1.10083107  0.        ]
#  [ 0.19028998 -0.01032709  1.        ]
#  [ 0.00976696 -0.02053641  1.        ]
#  ...
#  [-0.10391518  0.34638192  1.        ]
#  [ 0.24709879 -0.16289625  1.        ]
#  [-0.12695428  0.74982337  0.        ]]
#
# -----------------------------
# Época:  80
#
# Conjunto de dados embaralhado:
#  [[-0.31310084  0.27736732  1.        ]
#  [-0.20009509  0.37511566  1.        ]
#  [ 1.4187099  -0.14253384  0.        ]
#  ...
#  [-0.26839638  1.12152776  0.        ]
#  [-0.03746807  1.32508045  0.        ]
#  [-0.19908835  0.12926358  1.        ]]
#
# -----------------------------
# Época:  81
#
# Conjunto de dados embaralhado:
#  [[-0.33000132  0.07234854  1.        ]
#  [ 0.08179828 -0.09956027  1.        ]
#  [-0.0294872   0.13216526  1.        ]
#  ...
#  [-0.20389569  0.36597829  1.        ]
#  [ 0.2123362   0.02517371  1.        ]
#  [-0.04716837  0.19363929  1.        ]]
#
# -----------------------------
# Época:  82
#
# Conjunto de dados embaralhado:
#  [[ 0.12052833  0.52761443  1.        ]
#  [ 0.25776183  0.03455125  1.        ]
#  [-0.05049252 -0.25006668  1.        ]
#  ...
#  [-0.29322959 -0.09065359  1.        ]
#  [ 0.27534583  0.92380154  0.        ]
#  [-0.13286697  1.30171974  0.        ]]
#
# -----------------------------
# Época:  83
#
# Conjunto de dados embaralhado:
#  [[-0.12490354  0.73283285  0.        ]
#  [ 0.2123362   0.02517371  1.        ]
#  [-0.07113236  1.08579579  0.        ]
#  ...
#  [ 0.8098433   0.07540675  0.        ]
#  [-0.04716837  0.19363929  1.        ]
#  [-0.09127282  0.28768163  1.        ]]
#
# -----------------------------
# Época:  84
#
# Conjunto de dados embaralhado:
#  [[ 0.00976696 -0.02053641  1.        ]
#  [-0.33711565  0.94927484  0.        ]
#  [ 0.05786483 -0.36451414  1.        ]
#  ...
#  [-0.0547258  -0.11131214  1.        ]
#  [-0.02677506  0.19158953  1.        ]
#  [ 0.34015635  0.06961302  1.        ]]
#
# -----------------------------
# Época:  85
#
# Conjunto de dados embaralhado:
#  [[ 0.89238603 -0.27421654  0.        ]
#  [-0.34226827  1.29302582  0.        ]
#  [ 0.28066172  0.13031361  1.        ]
#  ...
#  [ 0.15252857  0.01744889  1.        ]
#  [ 0.00866547  0.79757433  0.        ]
#  [ 0.08097161  0.30854443  1.        ]]
#
# -----------------------------
# Época:  86
#
# Conjunto de dados embaralhado:
#  [[ 0.24709879 -0.16289625  1.        ]
#  [-0.19087107  1.1429872   0.        ]
#  [ 1.27271431 -0.30512302  0.        ]
#  ...
#  [-0.33000132  0.07234854  1.        ]
#  [ 1.4187099  -0.14253384  0.        ]
#  [ 0.28382866 -0.00689202  1.        ]]
#
# -----------------------------
# Época:  87
#
# Conjunto de dados embaralhado:
#  [[-0.28552876 -0.16910219  1.        ]
#  [-0.03486406  1.15509737  0.        ]
#  [-0.3001711   0.32724374  1.        ]
#  ...
#  [-0.31482467  0.02071152  1.        ]
#  [-0.01442025 -0.02745483  1.        ]
#  [ 0.20851547  0.87522108  0.        ]]
#
# -----------------------------
# Época:  88
#
# Conjunto de dados embaralhado:
#  [[-0.32030378 -0.05453506  1.        ]
#  [ 0.05786483 -0.36451414  1.        ]
#  [ 0.46304142  0.09405471  1.        ]
#  ...
#  [ 0.00866547  0.79757433  0.        ]
#  [-0.06832331  1.1562397   0.        ]
#  [-0.0054924  -0.30231266  1.        ]]
#
# -----------------------------
# Época:  89
#
# Conjunto de dados embaralhado:
#  [[-0.07849193  1.09714508  0.        ]
#  [ 0.14000195  1.0836725   0.        ]
#  [ 0.19028998 -0.01032709  1.        ]
#  ...
#  [ 0.04322791 -0.0461912   1.        ]
#  [ 0.04253339  0.4469942   1.        ]
#  [-0.29322959 -0.09065359  1.        ]]
#
# -----------------------------
# Época:  90
#
# Conjunto de dados embaralhado:
#  [[ 0.0114998  -0.05939114  1.        ]
#  [-0.2502875   0.13876078  1.        ]
#  [-0.13398331  1.03761866  0.        ]
#  ...
#  [ 0.14555276  0.70970773  0.        ]
#  [-0.20009509  0.37511566  1.        ]
#  [-0.13286697  1.30171974  0.        ]]
#
# -----------------------------
# Época:  91
#
# Conjunto de dados embaralhado:
#  [[ 8.24192013e-02  1.06606167e-03  1.00000000e+00]
#  [ 2.57761829e-01  3.45512494e-02  1.00000000e+00]
#  [ 1.75376034e-01  1.78265569e-01  1.00000000e+00]
#  ...
#  [ 5.78648298e-02 -3.64514140e-01  1.00000000e+00]
#  [ 8.92386035e-01 -2.74216540e-01  0.00000000e+00]
#  [-1.90871067e-01  1.14298720e+00  0.00000000e+00]]
#
# -----------------------------
# Época:  92
#
# Conjunto de dados embaralhado:
#  [[-0.29356844  0.00599321  1.        ]
#  [-0.00940128 -0.10654841  1.        ]
#  [ 0.2367801   0.37531654  1.        ]
#  ...
#  [ 0.20013586 -0.41657686  1.        ]
#  [ 0.14814828  1.19025708  0.        ]
#  [ 0.00842475  0.20229318  1.        ]]
#
# -----------------------------
# Época:  93
#
# Conjunto de dados embaralhado:
#  [[-0.28552876 -0.16910219  1.        ]
#  [ 0.46304142  0.09405471  1.        ]
#  [ 0.0114998  -0.05939114  1.        ]
#  ...
#  [-0.00940128 -0.10654841  1.        ]
#  [ 0.9692525  -0.10775797  0.        ]
#  [ 0.28382866 -0.00689202  1.        ]]
#
# -----------------------------
# Época:  94
#
# Conjunto de dados embaralhado:
#  [[-0.22958441  1.05209844  0.        ]
#  [-0.0054924  -0.30231266  1.        ]
#  [-0.06282733 -0.32877261  1.        ]
#  ...
#  [ 0.21675147  0.54097717  1.        ]
#  [ 0.22245222 -0.2466912   1.        ]
#  [-0.03746807  1.32508045  0.        ]]
#
# -----------------------------
# Época:  95
#
# Conjunto de dados embaralhado:
#  [[-0.2502875   0.13876078  1.        ]
#  [ 0.05786483 -0.36451414  1.        ]
#  [ 0.12052833  0.52761443  1.        ]
#  ...
#  [-0.12695428  0.74982337  0.        ]
#  [ 0.26072056 -0.14729552  1.        ]
#  [ 0.2123362   0.02517371  1.        ]]
#
# -----------------------------
# Época:  96
#
# Conjunto de dados embaralhado:
#  [[-0.0150527  -0.12832773  1.        ]
#  [ 0.30278194  0.95606248  0.        ]
#  [ 1.02800469 -0.15938552  0.        ]
#  ...
#  [-0.05039096 -0.43980938  1.        ]
#  [ 0.09475184  0.00442865  1.        ]
#  [ 0.15207387 -0.1526586   1.        ]]
#
# -----------------------------
# Época:  97
#
# Conjunto de dados embaralhado:
#  [[-0.29322959 -0.09065359  1.        ]
#  [-0.0150527  -0.12832773  1.        ]
#  [-0.04148642  0.99913985  0.        ]
#  ...
#  [ 0.07988839  0.21101297  1.        ]
#  [-0.11163154  0.00851976  1.        ]
#  [-0.1576937   0.74716362  0.        ]]
#
# -----------------------------
# Época:  98
#
# Conjunto de dados embaralhado:
#  [[-0.10074294 -0.31860073  1.        ]
#  [ 0.6876728   0.14567997  0.        ]
#  [ 0.25843371 -0.12301855  1.        ]
#  ...
#  [ 0.89238603 -0.27421654  0.        ]
#  [-0.06856801  0.16646269  1.        ]
#  [ 0.07785338  0.2471932   1.        ]]
#
# -----------------------------
# Época:  99
#
# Conjunto de dados embaralhado:
#  [[ 0.32202822  0.9463054   0.        ]
#  [ 0.06627455 -0.26057051  1.        ]
#  [-0.22615337  0.1493509   1.        ]
#  ...
#  [-0.29322959 -0.09065359  1.        ]
#  [-0.02677506  0.19158953  1.        ]
#  [ 0.08179828 -0.09956027  1.        ]]
#
# -----------------------------
# Época:  100
#
# Total de épocas:  100
# Total de ajustes feitos nos pesos:  1730

# %%
n.mostra_grafico()

# %%
def previsao():
    real = []
    previsto = []
    numero_de_acertos = 0
    numero_de_erros   = 0
    for i in n.x_teste:
        entrada = np.concatenate((np.array([n.vies]), i[:2]))
        
        yd = int(i[2:])
        yr = round(entrada.dot(n.pesos),4)
        yr = n.funcao_ativacao(yr)
        
        if(yr == yd):
            numero_de_acertos+=1
        else:
            numero_de_erros+=1
        
        real.append(yd)
        previsto.append(yr)
        
    acc = numero_de_acertos/ (numero_de_acertos+numero_de_erros)
    return numero_de_acertos, numero_de_erros, real, previsto, acc

# %%
numero_de_acertos, numero_de_erros, real, previsto, acc = previsao()

# %%
print("Quantidade de acertos: ", numero_de_acertos, "\nQuantidade de erros  : " ,numero_de_erros)
# Out:
# Quantidade de acertos:  210
# Quantidade de erros  :  30

# %% [markdown]
# ## Matriz de confusão

# %%
results = {'real': real, 'previsto': previsto}
results_df = pd.DataFrame.from_dict(results)
confusion_matrix = pd.crosstab(results_df['real'], results_df['previsto'], rownames=['Real'], colnames=['Previsto'])
sn.heatmap(confusion_matrix, annot=True, fmt="d")
plt.show()

# %% [markdown]
# ## Acurácia

# %%
print("A acurácia é:", acc)
# Out:
# A acurácia é: 0.875

# %%
confusion_matrix.values
# Out:
# array([[133,  30],
#        [  0,  77]], dtype=int64)

# %%
tn = confusion_matrix.values[0][0]
fp = confusion_matrix.values[0][1]
fn = confusion_matrix.values[1][0]
tp = confusion_matrix.values[1][1]
tn, fp, fn, tp
# Out:
# (133, 30, 0, 77)

# %% [markdown]
# ## Precisão

# %%
precision = tp/(tp+fp)
print("A precisao e:", precision)
# Out:
# A precisao e: 0.719626168224299

# %% [markdown]
# ## Revocação

# %%
recall = tp/(tp+fn)
print("A revocacao e:", recall)
# Out:
# A revocacao e: 1.0

# %% [markdown]
# ## F-Score

# %%
f_score = (2*(precision*recall))/(precision+recall)
print("O valor de F-Score e:", f_score)
# Out:
# O valor de F-Score e: 0.8369565217391304

# %% [markdown]
# ## Qualidade da Solução
#
# A acurácia do modelo treinado perante o conjunto de testes é de 87,50%, onde de 240 exemplos de teste, apenas 30 tiveram uma saída incorreta. A precisão foi de 0.71, a revocação de 1.0, enquanto o F-Score (média harmônica entre precisão e revocação) foi de 0.83. A partir desses resultados podemos dizer que o modelo (nessas condições, levando em consideração esses pesos, a taxa de aprendizagem e o valor de ϑ) é satisfatório, com uma alta acurácia e o F-Score está relativamente próximo de 1.

# %% [markdown]
# ## Solução do Perceptron com gráficos usando dados de treinamento e de teste

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

fig.set_figheight(4)
fig.set_figwidth(16)

fig.suptitle("Solução do Perceptron")
ax1.set_title("Treinamento")
ax2.set_title("Teste")

ponto1 = [0,n.x1]
ponto2 = [n.x2,0]
x_values = [ponto1[0], ponto2[0]]
y_values = [ponto1[1], ponto2[1]]

#Treino
for i in n.x_treino:
    x = i[0]
    y = i[1]
    yd = int(i[2])
    if(yd >= 1):
        ax1.scatter(x,y, color='r', s=8)
    else:
        ax1.scatter(x,y, color='b', s=8)

#Teste
for i in n.x_teste:
    x = i[0]
    y = i[1]
    yd = int(i[2])
    if(yd >= 1):
        ax2.scatter(x,y, color='r', s=8)
    else:
        ax2.scatter(x,y, color='b', s=8)

ax1.plot(x_values, y_values)
ax2.plot(x_values, y_values)
